# %% [markdown]
# ##### Exercício 1 - Calcule a soma dos elementos da  tupla 'my_tuple'

# %%
my_tuple = 1, 2, 3, 4, 5
print(sum(my_tuple))
# Out:
# 15

# %% [markdown]
# ##### Exercício 2 - Retorne o segundo elemento da tupla 'my_tuple'

# %%
my_tuple = 1, 2, 3, 4, 5
print(my_tuple[1])
# Out:
# 2

# %% [markdown]
# ##### Exercício 3 - Encontrar o erro no código abaixo

# %%
my_tuple = 1, 2, 3, 4, 5
# uma tupla não pode ter seus elementos alterados, são read-only
#my_tuple.remove(1)
print(my_tuple)
# Out:
# (1, 2, 3, 4, 5)
